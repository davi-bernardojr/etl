# %%
url = 'https://sdw-2023-prd.up.railway.app'
oepnai_api_key = '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'
#url = 'https://sdw-2023-prd.up.railway.app/users/{id}'

# %%
import pandas as pd
import os
import openai
import requests 
import json

df = pd.read_csv('sdw2023.csv')
userIds = df['userID'].tolist()
print(userIds)
# Out:
# [1091, 1101, 1102]

# %%
def get_User(id):
    response = requests.get(f'{url}/users/{id}')
    return response.json() if response.status_code == 200 else None

users = [user for id in userIds if (user := get_User(id)) is not None]

print(json.dumps(users, indent=2))
# Out:
# [
#   {
#     "id": 1091,
#     "name": "Daverson",
#     "account": {
#       "id": 1155,
#       "number": "99944494",
#       "agency": "6666",
#       "balance": 0.0,
#       "limit": 500.0
#     },
#     "card": {
#       "id": 1063,
#       "number": "0303 0606 1989 1111",
#       "limit": 1000.0
#     },
#     "features": [],
#     "news": [
#       {
#         "id": 2506,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Daverson, descubra como os investimentos podem transformar sua vida financeira. Comece hoje mesmo!"
#       },
#       {
#         "id": 3163,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Invista no seu futuro financeiro!"
#       },
#       {
#         "id": 3164,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
# ...

# %%
openai.api_key = oepnai_api_key

def generate_ai_news(user):
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo",
      messages=[
        {
            "role": "system", 
            "content": "Você é um especialista em marketing bancário."
        },
        {
            "role": "user", 
            "content": f"Crie uma menssagem para {user['name']} sobre a importancia dos investimentos (máximo de 100 caracteres.)"
        }
      ]
    )
    return completion.choices[0].message.content.strip('\"')

def update_user(user):
    response = requests.put(f"{url}/users/{user['id']}", json=user)
    return True if response.status_code == 200 else False

for user in users:
    news = generate_ai_news(user)
    print(news)
    user['news'].append({
        "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
        "description" : news
    })
    print(f"Cliente {user['name']} atualizado." if update_user(user) == True else f"Cliente {user['name']} não atualizado.")
# Out:
# Invista seu futuro, faça seu dinheiro crescer!
# Cliente Daverson atualizado.
# Invista hoje, colha amanhã!
# Cliente Lukerson atualizado.
# Invista e garanta seu futuro financeiro.
# Cliente Anderson atualizado.
